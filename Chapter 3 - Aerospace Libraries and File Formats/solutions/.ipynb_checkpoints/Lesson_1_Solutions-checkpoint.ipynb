# %% [markdown]
# # Lesson 1 Exercise Solutions

# %% [markdown]
# ## Exercise 1: Visualizing a FITS File
#
# #### Objectives:
# - Read the `M6707HH.fits` file using Astropy
# - Print out header information for the Primary HDU
# - Print the dimensions of the FITS Image
# - Visualize the FITS file

# %%
from astropy.io import fits

# %%
import matplotlib.pyplot as plt
from astropy.visualization import astropy_mpl_style
from astropy.utils.data import get_pkg_data_filename
plt.style.use(astropy_mpl_style)

# %%
with fits.open('../M6707HH.fits') as hdul:
    hdul.info()
    print(hdul[0].header)
# Out:
# Filename: ../M6707HH.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     104   (1059, 1059)   int16
# SIMPLE  =                    T /FITS header                                     BITPIX  =                   16 /No.Bits per pixel                               NAXIS   =                    2 /No.dimensions                                   NAXIS1  =                 1059 /Length X axis                                   NAXIS2  =                 1059 /Length Y axis                                   DATE    = '03/03/08          ' /Date of FITS file creation                      ORIGIN  = 'CASB -- STScI     ' /Origin of FITS image                            PLTLABEL= 'E438              ' /Observatory plate label                         PLATEID = '07HH              ' /GSSS Plate ID                                   REGION  = 'XE486             ' /GSSS Region Name                                DATE-OBS= '29/11/51          ' /UT date of Observation                          UT      = '12:07:00.00       ' /UT time of observation                          EPOCH   =  1.9519110107422E+03 /Epoch of plate                                  PLTRAH  =                    8 /Plate center RA                                 PLTRAM  =                   55 /                                                PLTRAS  =  5.5048340000000E+01 /                                                PLTDECSN= '+                 ' /Plate center Dec                                PLTDECD =                   11 /                                                PLTDECM =                   26 /                                                PLTDECS =  5.8315540000000E+01 /                                                EQUINOX =  2.0000000000000E+03 /Julian Reference frame equinox                  EXPOSURE=  5.0000000000000E+01 /Exposure time minutes                           BANDPASS=                    8 /GSSS Bandpass code                              PLTGRADE=                    0 /Plate grade                                     PLTSCALE=  6.7200000000000E+01 /Plate Scale arcsec per mm                       SITELAT = '+33:24:24.00      ' /Latitude of Observatory                         SITELONG= '-116:51:48.00     ' /Longitude of Observatory                        TELESCOP= 'Palomar 48-inch Schmidt'/Telescope where plate taken                 CNPIX1  =                 8734 /X corner  (pixels)                              CNPIX2  =                 7218 /Y corner                                        DATATYPE= 'INTEGER*2         ' /Type of Data                                    SCANIMG = 'XE486_07HH_00_03.PIM'/Name of original scan                          SCANNUM =                    0 /Identifies scan of the plate                    DCHOPPED=                    T /Image repaired for chopping effects             DSHEARED=                    F /Image repaired for shearing effects             DSCNDNUM=                    3 /Identifies descendant of plate scan image       XPIXELSZ=  2.5284450000000E+01 /X pixel size microns                            YPIXELSZ=  2.5284450000000E+01 /Y pixel size microns                            PPO1    =  0.0000000000000E+00 /Orientation Coefficients                        PPO2    =  0.0000000000000E+00 /                                                PPO3    =  1.7497471555000E+05 /                                                PPO4    =  0.0000000000000E+00 /                                                PPO5    =  0.0000000000000E+00 /                                                PPO6    =  1.7497471555000E+05 /                                                AMDX1   =  6.7246080000000E+01 /Plate solution x coefficients                   AMDX2   =  7.1037040000000E-01 /                                                AMDX3   = -6.6940350000000E+01 /                                                AMDX4   = -9.5749640000000E-06 /                                                AMDX5   = -8.6157290000000E-06 /                                                AMDX6   =  0.0000000000000E+00 /                                                 ...

# %%
image_file = get_pkg_data_filename('../M6707HH.fits')
image_data = fits.getdata(image_file, ext=0)

# %%
print(image_data.shape)
# Out:
# (1059, 1059)

# %%
plt.figure()
plt.imshow(image_data)
plt.colorbar()

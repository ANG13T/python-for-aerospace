# %% [markdown]
# # Lesson 3: Skyfield and JPL Horizons

# %% [markdown]
# ## What is Skyfield?
# Skyfield is a Python library for astronomical calculations. It provides high-precision ephemerides (predictions of celestial positions and motions) for celestial bodies such as planets, moons, and stars.
#
# We can use Skyfield to make enhanced astronomical visualizations such as the following:
#
# ![https://qph.cf2.quoracdn.net/main-qimg-033a5a471502e23e894233feecf507cf](https://qph.cf2.quoracdn.net/main-qimg-033a5a471502e23e894233feecf507cf)
#
# [Image Source](https://www.quora.com/How-do-I-code-in-Python-to-track-the-satellite-current-location-of-satellites-orbiting-the-Earth)
#
# Learn more about it here:
#
# [https://rhodesmill.org/skyfield/](https://rhodesmill.org/skyfield/)

# %% [markdown]
# ## What is JPL Horizons?
# The Horizons system is an online service provided by NASA's Jet Propulsion Laboratory (JPL) that allows users to access ephemeris data for solar system bodies. Ephemeris data is essentially a table of positions for time spans for a specific celestial body.
#
# You can obtain the latest ephemeris data from the Horizons systems here:
#
# [https://ssd.jpl.nasa.gov/horizons/](https://ssd.jpl.nasa.gov/horizons/).
#
# We can obtain JPL Horizons data from the `astroquery` library.

# %%
from astroquery.jplhorizons import Horizons

# %% [markdown]
# The below code obtains the ephemerides data for a celestial body with the following specifications:
# - `id`: target celestial object (celestial object's designation ID)
# - `location`: specifies the observer's location from which you want to compute the ephemeris data
# - `epochs`: specifies the time range and time step for which you want to retrieve ephemeris data

# %%
obj = Horizons(id='3552', location='568', epochs={'start':'2020-02-10', 'stop':'2022-12-31','step':'1y'})
eph = obj.ephemerides()
print(eph)
# Out:
#         targetname            datetime_str   datetime_jd   H    G   solar_presence lunar_presence     RA    ... XBand_3sigma DoppDelay_3sigma true_anom  hour_angle  alpha_true  PABLon   PABLat
#            ---                    ---             d       mag  ---       ---            ---          deg    ...      Hz             s            deg         h          deg       deg      deg
# -------------------------- ----------------- ----------- ----- ---- -------------- -------------- --------- ... ------------ ---------------- --------- ------------ ---------- -------- -------
# 3552 Don Quixote (1983 SA) 2020-Feb-10 00:00   2458889.5 13.05 0.15              *                 84.85481 ...         0.32         0.000454   147.887 -6.747683249     9.3278  91.7494 32.0754
# 3552 Don Quixote (1983 SA) 2021-Feb-10 00:00   2459255.5 13.05 0.15              *              m 115.50012 ...         0.36         0.000338  162.6623 -8.739542336     6.0059 110.4549 28.7055
# ...

# %% [markdown]
# ## Exercise 1: Obtaining JPL Horizons Data
#
# #### Objectives:
# - Import the Horizons function within `astroquery`
# - Obtain ephemerides for a comet named Eros (id = 433) relative to the sun (id = 500@10)
# - Start at `2020-02-10` and end at `2022-12-31` with `1 year` step
# - Print out the ephemerides data

# %% [markdown]
# ## Make your own Sky Map 🌌

# %% [markdown]
# ### Import Libraries

# %%
from skyfield.api import Star, load, wgs84
from skyfield.data import hipparcos
from skyfield.projections import build_stereographic_projection
import matplotlib.pyplot as plt
from matplotlib.collections import LineCollection
from matplotlib.patches import Circle

# %% [markdown]
# ### Loading Data using Skyfield
# The following code snippet uses the `load` function to import the ephemeris data for DE421 (one of the most accurate ephemeris models available). In this case, we focus on obtaining ephemeris data specifically for the Jupiter Barycenter (center of mass of the Jupiter system).

# %%
ts = load.timescale()

# INPUT YOUR TIME SCALE BELOW
t = ts.utc(2021, 2, 26, 15, 19)

# INPUT YOUR GEOCOORDINATES BELOW
lat, long = 34.118, -118.3

# Obtaining Planet Data 
planets = load('de421.bsp')
jupiter = planets['Jupiter Barycenter']
earth = planets['Earth Barycenter']
barycentric = jupiter.at(t)

# Obtaining Star Data
with load.open(hipparcos.URL) as f:
    stars = hipparcos.load_dataframe(f)

# %% [markdown]
# ### Observer and Position
# We define an observer variable using our geocoordinates within the world geodetic system (WGS84).
# Then, we define a specific point in the sky the observer will look at specified in terms of elevation angle (alt_degrees) and azimuth (az_degrees).
#
#
# ![image.png](attachment:deb0c96a-6b10-4dbc-b468-5c4d6d0039d6.png)
#
# [Image Source](https://en.wikipedia.org/wiki/Azimuth)

# %%
observer = wgs84.latlon(latitude_degrees=lat, longitude_degrees=long).at(t)

# Position in the sky the observer will look at
position = observer.from_altaz(alt_degrees=90, az_degrees=0)

# %% [markdown]
# ### Center the Observer and Build a 180 degree View Projection

# %%
# Center the Observation
ra, dec, distance = observer.radec()
center_object = Star(ra=ra, dec=dec)

# Find position of Jupiter relative to Earth and build a 180 deg projection
center = earth.at(t).observe(center_object)
projection = build_stereographic_projection(center)
field_of_view_degrees = 180.0

# %% [markdown]
# ### Calculate Star Positions

# %%
star_positions = earth.at(t).observe(Star.from_dataframe(stars))
stars['x'], stars['y'] = projection(star_positions)

# %% [markdown]
# ### Configuring Graph Values

# %%
chart_size = 10
max_star_size = 100
limiting_magnitude = 10

# Create a filter that only shows stars of a specific magnitude or greater
bright_stars = (stars.magnitude <= limiting_magnitude)
magnitude = stars['magnitude'][bright_stars]

# Size of the star depends on the star size and magnitude of brightness
marker_size = max_star_size * 10 ** (magnitude / -2.5)

# %% [markdown]
# ### Creating the Visualization

# %%
fig, ax = plt.subplots(figsize=(chart_size, chart_size))
    
border = plt.Circle((0, 0), 1, color='black', fill=True)
ax.add_patch(border)

ax.scatter(stars['x'][bright_stars], stars['y'][bright_stars],
           s=marker_size, color='white', marker='.', linewidths=0, 
           zorder=2)

horizon = Circle((0, 0), radius=1, transform=ax.transData)
for col in ax.collections:
    col.set_clip_path(horizon)

ax.set_xlim(-1, 1)
ax.set_ylim(-1, 1)
plt.title(f"Sky Map of Jupyter Barycenter relative to ({lat}, {long})")
plt.show()

# %% [markdown]
# Congrats! You learned how to use skyfield in conjunction with JPL Horizons data! In the next lesson, we will cover how you can leverage specutils and photutils to do more astronomical research.
